# %% [markdown]
# # **Tugas 1 | Crawling Twitter with snscrape**

# %% [markdown]
# Data crawling adalah proses automatis untuk mengumpulkan dan mengindeks data dari berbagai sumber seperti situs web, database, atau dokumen. Proses ini menggunakan software atau aplikasi khusus yang disebut `"snscrape"` untuk mengakses sumber data dan mengambil informasi yang dibutuhkan.

# %% [markdown]
# ## Install Libary

# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Inisialisasi Variable

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import os

# %% [markdown]
# ## Proses Crawling Data Anies Baswedan

# %%
query = "anies baswedan"
tweets = []
limit = 500

#  # Mengambil data twitter dengan kata kunci anies baswedan
# for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
#     # print(vars(tweet))
#     # break
#     if len(tweets) == limit:
#         break
#     else:
      
#         tweets.append([tweet.date, tweet.username, tweet.content])

## Convert to DATA FRAME
# df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
# print(df)

# to save to csv
#path = "/content/drive/MyDrive/prosaindata/DataCrawling/Data_twitter_snt.csv"

path = "https://raw.githubusercontent.com/LALA09-erha/File-semester5/master/PSD/Data%20Crawling/Data_twitter_snt.csv"


# Untuk mengecek apakah file sudah terdapat pada folder Jika tidak Maka Simpan
# if( os.path.exists(path) == True):
#     os.remove(path)
# df.to_csv(path)
df = pd.read_csv(path)
df
# Out:
#      Unnamed: 0                       Date             User  \
# 0             0  2023-04-15 17:47:07+00:00     Kaki_Langith
# 1             1  2023-04-15 17:46:55+00:00         RomitsuT
# 2             2  2023-04-15 17:45:07+00:00   PutriSemesta45
# 3             3  2023-04-15 17:43:00+00:00   MarkersAndSuch
# 4             4  2023-04-15 17:41:22+00:00   PutriSemesta45
# ..          ...                        ...              ...
# 495         495  2023-04-15 11:08:08+00:00      yuemiemieya
# 496         496  2023-04-15 11:06:56+00:00    NabilBTN08043
# 497         497  2023-04-15 11:06:56+00:00      yuemiemieya
# 498         498  2023-04-15 11:05:42+00:00  Wahyudi96449723
# 499         499  2023-04-15 11:04:42+00:00   JhonniSinaga20
#
#                                                  Tweet
# 0    @TradeInves @tanyakanrl Kalau @aniesbaswedan k...
# 1    Dia memang seorang PEMIMPIN. \n\nDia bukan sek...
# 2    kalo disebut lahan subur sih jelas cuma kan ok...
# ...
