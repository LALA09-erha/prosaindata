# %% [markdown]
# # **Tugas 1 | Scraping Twitter with Twint**

# %%
pip install --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-39y52xlv/twint_b97fea7210a148a9b08b180119bc09d1
#   Running command git clone --filter=blob:none --quiet https://github.com/twintproject/twint.git /tmp/pip-install-39y52xlv/twint_b97fea7210a148a9b08b180119bc09d1
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
#   Resolved https://github.com/twintproject/twint.git to commit origin/master
#   Preparing metadata (setup.py) ... done
# ...

# %%
pip install nest_asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import twint
import nest_asyncio
import os
nest_asyncio.apply()

# %%
twi = twint.Config()
path = "/content/drive/MyDrive/prosaindata/DataCrawling/Data_twitter.csv"
twi.Search = 'anies baswedan'
# twi.Location = True
twi.Store_csv = True
twi.Custom["tweet"] = ["date","language", "username","name", "tweet"]
twi.Limit = 500
if( os.path.exists(path) == True):
    os.remove(path)

twi.Output = path
twint.run.Search(twi)
# Out:
# 1626630296572506112 2023-02-17 17:10:58 +0000 <FirmanMau14n4> @BellaDi00561934 @syahri_alfu @AaHendrik8 @aniesbaswedan @NasDem @PDemokrat @PKSejahtera Terus hasil pemikiranmu untuk mengatasi utang negara itu apa?
# 1626630130536939520 2023-02-17 17:10:19 +0000 <BTinoq> @Chynthia_K Yg ini memang kurang keren,,  masih keren saat shoting sinetron GEROBAK SAMPAH terlihat Anies sangat menjiwai sebagai sampah bahkan gerobaknya sebagai figuran nampak sangat natural, saking naturalnya bahkan byk yg tdk bisa membedakan mana GEROBAK dan mana ANIES, @aniesbaswedan
# 1626630128062312448 2023-02-17 17:10:18 +0000 <PiakRaden> @MuhiqR @NasDem @aniesbaswedan Di Sulawesi ,Jawa barat,Medan anies disambut dgn tarian bahkan di Papua anies di baptis dengan nama Yohanes kok..😂
# 1626630034898456577 2023-02-17 17:09:56 +0000 <JenarSitiSyeh1> @rudiabdedey @ch_chotimah2 @Yurissa_Samosir @aniesbaswedan @ganjarpranowo Opo iyo...??? 🤪🤪
# ...
